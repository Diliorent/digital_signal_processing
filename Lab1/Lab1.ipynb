# %% [markdown]
# Завдання
# Створити скрипт Python або Notebook з наступним функціоналом:
#
# 1. Зчитати та завантажити тестове чорно-біле та кольорове зображення.
# 2. Відобразити чорно-біле та кольорове зображення.
# 3. Перетворити зображення з колірної моделі BGR в колірні моделі RGB і HSV та відобразити.
# 4. Окремо відобразити колірні канали для зображень із колірними моделями RGB та HSV.
# 5. Скопіювати область інтересу (Region of Interest) чорно-білого зображення, використовуючи наступні діапазони 0:img.shape[0]/2, 0:img.shape[1]/2.
# 6. Зберегти область інтересу (Region of Interest).
#
# Додаткові завдання:
#
# 1. Перетворити зображення з колірної моделі BGR в колірну модель HSV за допомогою формул.
# 2. Реалізувати функцію для визначення колірної відстані (Delta E76, Delta E94).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#img_co = cv2.cvtColor(cv2.imread("/content/stupidDOPE-470x470.jpg"), cv2.COLOR_BGR2RGB)
img_co = cv2.imread("/content/stupidDOPE-470x470.jpg")
img_gs = cv2.imread("/content/stupidDOPE-470x470.jpg", cv2.IMREAD_GRAYSCALE)

# %%
fig =plt.figure(figsize=(10,5))
fig.add_subplot(1, 2, 1)
plt.imshow(img_gs, cmap='gray')
fig.add_subplot(1, 2, 2)
#plt.figure(figsize=(5, 5))
plt.imshow(img_co)
plt.show();

# %%
img_rgb = cv2.cvtColor(cv2.imread("/content/stupidDOPE-470x470.jpg"), cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(cv2.imread("/content/stupidDOPE-470x470.jpg"), cv2.COLOR_BGR2HSV)
fig =plt.figure(figsize=(10,5))
fig.add_subplot(1, 2, 1)
plt.imshow(img_rgb)
fig.add_subplot(1, 2, 2)
plt.imshow(img_hsv)

plt.show();

# %%
plt.figure(figsize=(10, 10))

plt.subplot(231);
R = np.zeros(img_rgb.shape, dtype='uint8')
R[:, :, 0] = img_rgb[:, :, 0]
plt.imshow(R)

plt.subplot(232);
G = np.zeros(img_rgb.shape, dtype='uint8')
G[:, :, 1] = img_rgb[:, :, 1]
plt.imshow(G)

plt.subplot(233);
B = np.zeros(img_rgb.shape, dtype='uint8')
B[:, :, 2] = img_rgb[:, :, 2]
plt.imshow(B)

plt.subplot(234);
R = np.zeros(img_hsv.shape, dtype='uint8')
R[:, :, 0] = img_hsv[:, :, 0]
plt.imshow(R)

plt.subplot(235);
G = np.zeros(img_hsv.shape, dtype='uint8')
G[:, :, 1] = img_hsv[:, :, 1]
plt.imshow(G)

plt.subplot(236);
B = np.zeros(img_hsv.shape, dtype='uint8')
B[:, :, 2] = img_hsv[:, :, 2]
plt.imshow(B)


plt.show()

# %% [markdown]
# Скопіювати область інтересу (Region of Interest) чорно-білого зображення, використовуючи наступні діапазони 0:img.shape[0]/2, 0:img.shape[1]/2.

# %%
plt.figure(figsize=(10,10));
img_crop_gs = img_gs[0:int(img_gs.shape[0]/2), 0:int(img_gs.shape[1]/2)];
plt.imshow(img_crop_gs, cmap='gray');
cv2.imwrite("img_crop_gs", img)

# %% [markdown]
# Додаткові завдання:
#
# 1. Перетворити зображення з колірної моделі BGR в колірну модель HSV за допомогою формул.
# 2. Реалізувати функцію для визначення колірної відстані (Delta E76, Delta E94).
